# %% [markdown]
# <a href="https://colab.research.google.com/github/prakharmishra263139/DEMO_HOST/blob/master/OnlineRetailAanalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install fireducks
# !pip install openpyxl
# Out:
# Collecting fireducks
#   Downloading fireducks-1.2.4-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (1.0 kB)
# Collecting firefw==1.2.4 (from fireducks)
#   Downloading firefw-1.2.4-py3-none-any.whl.metadata (818 bytes)
# Requirement already satisfied: pandas<2.3.0,>=1.5.3 in /usr/local/lib/python3.11/dist-packages (from fireducks) (2.2.2)
# Requirement already satisfied: pyarrow<19.1,>=19.0 in /usr/local/lib/python3.11/dist-packages (from fireducks) (19.0.1)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas<2.3.0,>=1.5.3->fireducks) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas<2.3.0,>=1.5.3->fireducks) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<2.3.0,>=1.5.3->fireducks) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<2.3.0,>=1.5.3->fireducks) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas<2.3.0,>=1.5.3->fireducks) (1.17.0)
# Downloading fireducks-1.2.4-cp311-cp311-manylinux_2_28_x86_64.whl (7.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 33.0 MB/s eta 0:00:00
# Downloading firefw-1.2.4-py3-none-any.whl (12 kB)
# Installing collected packages: firefw, fireducks
# Successfully installed fireducks-1.2.4 firefw-1.2.4
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.9/250.9 kB 4.2 MB/s eta 0:00:00
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5

# %%
# %load_ext fireducks.pandas
import pandas as pd
from matplotlib import pyplot as plt

# %%
# !wget https://archive.ics.uci.edu/static/public/352/online+retail.zip
# Out:
# --2025-03-12 10:49:56--  https://archive.ics.uci.edu/static/public/352/online+retail.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘online+retail.zip’
#
# online+retail.zip       [    <=>             ]  22.62M  30.2MB/s    in 0.7s
#
# 2025-03-12 10:49:57 (30.2 MB/s) - ‘online+retail.zip’ saved [23715478]

# %%
# !unzip online+retail.zip
# Out:
# Archive:  online+retail.zip
#  extracting: Online Retail.xlsx

# %%
import time
stime = time.time()

# %%
df1 = pd.read_excel("Online Retail.xlsx", dtype={'InvoiceNo': 'string', 'StockCode': 'string', 'Description': 'string', 'Country': 'string'})
df1 = pd.concat([df1] * 60)
df1.shape
# Out:
# (32514540, 8)

# %%
df1.shape
# Out:
# (32514540, 8)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32514540 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   InvoiceNo    object
#  1   StockCode    object
#  2   Description  object
#  3   Quantity     int64
#  4   InvoiceDate  datetime64[ns]
#  5   UnitPrice    float64
#  6   CustomerID   float64
#  7   Country      object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 2.2+ GB

# %%
# DATA CLEANING : Handling Missing Values
df1.isnull().sum()
# Out:
# InvoiceNo            0
# StockCode            0
# Description      87240
# Quantity             0
# InvoiceDate          0
# UnitPrice            0
# CustomerID     8104800
# Country              0
# dtype: int64

# %%
df1[df1.Description.isnull()]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>InvoiceNo</th>
#       <th>StockCode</th>
#       <th>Description</th>
#       <th>Quantity</th>
#       <th>InvoiceDate</th>
#       <th>UnitPrice</th>
#       <th>CustomerID</th>
#       <th>Country</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>622</th>
#       <td>536414</td>
#       <td>22139</td>
#       <td>None</td>
#       <td>56</td>
#       <td>2010-12-01 11:52:00</td>
#       <td>0.0</td>
#       <td>NaN</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>1970</th>
#       <td>536545</td>
#       <td>21134</td>
#       <td>None</td>
#       <td>1</td>
#       <td>2010-12-01 14:32:00</td>
#       <td>0.0</td>
#       <td>NaN</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>1971</th>
#       <td>536546</td>
#       <td>22145</td>
#       <td>None</td>
#       <td>1</td>
#       <td>2010-12-01 14:33:00</td>
#       <td>0.0</td>
#       <td>NaN</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>1972</th>
#       <td>536547</td>
#       <td>37509</td>
#       <td>None</td>
#       <td>1</td>
#       <td>2010-12-01 14:33:00</td>
#       <td>0.0</td>
#       <td>NaN</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>1987</th>
#       <td>536549</td>
#       <td>85226A</td>
#       <td>None</td>
#       <td>1</td>
#       <td>2010-12-01 14:34:00</td>
#       <td>0.0</td>
#       <td>NaN</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>535322</th>
#       <td>581199</td>
#       <td>84581</td>
#       <td>None</td>
#       <td>-2</td>
#       <td>2011-12-07 18:26:00</td>
#       <td>0.0</td>
#       <td>NaN</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>535326</th>
#       <td>581203</td>
#       <td>23406</td>
#       <td>None</td>
#       <td>15</td>
#       <td>2011-12-07 18:31:00</td>
#       <td>0.0</td>
#       <td>NaN</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>535332</th>
#       <td>581209</td>
#       <td>21620</td>
#       <td>None</td>
#       <td>6</td>
#       <td>2011-12-07 18:35:00</td>
#       <td>0.0</td>
#       <td>NaN</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>536981</th>
#       <td>581234</td>
#       <td>72817</td>
#       <td>None</td>
#       <td>27</td>
#       <td>2011-12-08 10:33:00</td>
#       <td>0.0</td>
#       <td>NaN</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>538554</th>
#       <td>581408</td>
#       <td>85175</td>
#       <td>None</td>
#       <td>20</td>
#       <td>2011-12-08 14:06:00</td>
#       <td>0.0</td>
#       <td>NaN</td>
#       <td>United Kingdom</td>
#     </tr>
#   </tbody>
# </table>
# <p>87240 rows x 8 columns</p>
# </div>

# %%
df1[df1.StockCode=='22139'].Description.mode()
# Out:
# 0    RETROSPOT TEA SET CERAMIC 11 PC
# Name: Description, dtype: object

# %%
most_freq = df1[["StockCode", "Description"]].value_counts().reset_index()
most_freq
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>StockCode</th>
#       <th>Description</th>
#       <th>count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>85123A</td>
#       <td>WHITE HANGING HEART T-LIGHT HOLDER</td>
#       <td>138120</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>22423</td>
#       <td>REGENCY CAKESTAND 3 TIER</td>
#       <td>132000</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>85099B</td>
#       <td>JUMBO BAG RED RETROSPOT</td>
#       <td>129540</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>47566</td>
#       <td>PARTY BUNTING</td>
#       <td>103620</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>20725</td>
#       <td>LUNCH BAG RED RETROSPOT</td>
#       <td>98280</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>4787</th>
#       <td>DCGS0069</td>
#       <td>ebay</td>
#       <td>60</td>
#     </tr>
#     <tr>
#       <th>4788</th>
#       <td>DCGS0070</td>
#       <td>CAMOUFLAGE DOG COLLAR</td>
#       <td>60</td>
#     </tr>
#     <tr>
#       <th>4789</th>
#       <td>DCGS0073</td>
#       <td>ebay</td>
#       <td>60</td>
#     </tr>
#     <tr>
#       <th>4790</th>
#       <td>gift_0001_20</td>
#       <td>to push order througha s stock was</td>
#       <td>60</td>
#     </tr>
#     <tr>
#       <th>4791</th>
#       <td>m</td>
#       <td>Manual</td>
#       <td>60</td>
#     </tr>
#   </tbody>
# </table>
# <p>4792 rows x 3 columns</p>
# </div>

# %%
most_freq[most_freq.StockCode=="85123A"].head(1)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>StockCode</th>
#       <th>Description</th>
#       <th>count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>85123A</td>
#       <td>WHITE HANGING HEART T-LIGHT HOLDER</td>
#       <td>138120</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
most_freq = most_freq.groupby("StockCode").head(1)
most_freq
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>StockCode</th>
#       <th>Description</th>
#       <th>count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>85123A</td>
#       <td>WHITE HANGING HEART T-LIGHT HOLDER</td>
#       <td>138120</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>22423</td>
#       <td>REGENCY CAKESTAND 3 TIER</td>
#       <td>132000</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>85099B</td>
#       <td>JUMBO BAG RED RETROSPOT</td>
#       <td>129540</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>47566</td>
#       <td>PARTY BUNTING</td>
#       <td>103620</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>20725</td>
#       <td>LUNCH BAG RED RETROSPOT</td>
#       <td>98280</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>4785</th>
#       <td>DCGS0068</td>
#       <td>ebay</td>
#       <td>60</td>
#     </tr>
#     <tr>
#       <th>4786</th>
#       <td>DCGS0069</td>
#       <td>OOH LA LA DOGS COLLAR</td>
#       <td>60</td>
#     </tr>
#     <tr>
#       <th>4788</th>
#       <td>DCGS0070</td>
#       <td>CAMOUFLAGE DOG COLLAR</td>
#       <td>60</td>
#     </tr>
#     <tr>
#       <th>4789</th>
#       <td>DCGS0073</td>
#       <td>ebay</td>
#       <td>60</td>
#     </tr>
#     <tr>
#       <th>4791</th>
#       <td>m</td>
#       <td>Manual</td>
#       <td>60</td>
#     </tr>
#   </tbody>
# </table>
# <p>3958 rows x 3 columns</p>
# </div>

# %%
most_freq.columns = ["StockCode", "freq_Description", "Count"]

df2 = df1.merge(most_freq, on="StockCode", how="left")
df2.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>InvoiceNo</th>
#       <th>StockCode</th>
#       <th>Description</th>
#       <th>Quantity</th>
#       <th>InvoiceDate</th>
#       <th>UnitPrice</th>
#       <th>CustomerID</th>
#       <th>Country</th>
#       <th>freq_Description</th>
#       <th>Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>536365</td>
#       <td>85123A</td>
#       <td>WHITE HANGING HEART T-LIGHT HOLDER</td>
#       <td>6</td>
#       <td>2010-12-01 08:26:00</td>
#       <td>2.55</td>
#       <td>17850.0</td>
#       <td>United Kingdom</td>
#       <td>WHITE HANGING HEART T-LIGHT HOLDER</td>
#       <td>138120</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>536365</td>
#       <td>71053</td>
#       <td>WHITE METAL LANTERN</td>
#       <td>6</td>
#       <td>2010-12-01 08:26:00</td>
#       <td>3.39</td>
#       <td>17850.0</td>
#       <td>United Kingdom</td>
#       <td>WHITE METAL LANTERN</td>
#       <td>19680</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>536365</td>
#       <td>84406B</td>
#       <td>CREAM CUPID HEARTS COAT HANGER</td>
#       <td>8</td>
#       <td>2010-12-01 08:26:00</td>
#       <td>2.75</td>
#       <td>17850.0</td>
#       <td>United Kingdom</td>
#       <td>CREAM CUPID HEARTS COAT HANGER</td>
#       <td>17580</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>536365</td>
#       <td>84029G</td>
#       <td>KNITTED UNION FLAG HOT WATER BOTTLE</td>
#       <td>6</td>
#       <td>2010-12-01 08:26:00</td>
#       <td>3.39</td>
#       <td>17850.0</td>
#       <td>United Kingdom</td>
#       <td>KNITTED UNION FLAG HOT WATER BOTTLE</td>
#       <td>28380</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>536365</td>
#       <td>84029E</td>
#       <td>RED WOOLLY HOTTIE WHITE HEART.</td>
#       <td>6</td>
#       <td>2010-12-01 08:26:00</td>
#       <td>3.39</td>
#       <td>17850.0</td>
#       <td>United Kingdom</td>
#       <td>RED WOOLLY HOTTIE WHITE HEART.</td>
#       <td>26940</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df2['Description']=df2["freq_Description"]
df2.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>InvoiceNo</th>
#       <th>StockCode</th>
#       <th>Description</th>
#       <th>Quantity</th>
#       <th>InvoiceDate</th>
#       <th>UnitPrice</th>
#       <th>CustomerID</th>
#       <th>Country</th>
#       <th>freq_Description</th>
#       <th>Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>536365</td>
#       <td>85123A</td>
#       <td>WHITE HANGING HEART T-LIGHT HOLDER</td>
#       <td>6</td>
#       <td>2010-12-01 08:26:00</td>
#       <td>2.55</td>
#       <td>17850.0</td>
#       <td>United Kingdom</td>
#       <td>WHITE HANGING HEART T-LIGHT HOLDER</td>
#       <td>138120</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>536365</td>
#       <td>71053</td>
#       <td>WHITE METAL LANTERN</td>
#       <td>6</td>
#       <td>2010-12-01 08:26:00</td>
#       <td>3.39</td>
#       <td>17850.0</td>
#       <td>United Kingdom</td>
#       <td>WHITE METAL LANTERN</td>
#       <td>19680</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>536365</td>
#       <td>84406B</td>
#       <td>CREAM CUPID HEARTS COAT HANGER</td>
#       <td>8</td>
#       <td>2010-12-01 08:26:00</td>
#       <td>2.75</td>
#       <td>17850.0</td>
#       <td>United Kingdom</td>
#       <td>CREAM CUPID HEARTS COAT HANGER</td>
#       <td>17580</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>536365</td>
#       <td>84029G</td>
#       <td>KNITTED UNION FLAG HOT WATER BOTTLE</td>
#       <td>6</td>
#       <td>2010-12-01 08:26:00</td>
#       <td>3.39</td>
#       <td>17850.0</td>
#       <td>United Kingdom</td>
#       <td>KNITTED UNION FLAG HOT WATER BOTTLE</td>
#       <td>28380</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>536365</td>
#       <td>84029E</td>
#       <td>RED WOOLLY HOTTIE WHITE HEART.</td>
#       <td>6</td>
#       <td>2010-12-01 08:26:00</td>
#       <td>3.39</td>
#       <td>17850.0</td>
#       <td>United Kingdom</td>
#       <td>RED WOOLLY HOTTIE WHITE HEART.</td>
#       <td>26940</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df2.isnull().sum()
# Out:
# InvoiceNo                 0
# StockCode                 0
# Description            6720
# Quantity                  0
# InvoiceDate               0
# UnitPrice                 0
# CustomerID          8104800
# Country                   0
# freq_Description       6720
# Count                  6720
# dtype: int64

# %%
df2.dropna(subset=["Description"],inplace=True)
df2.isnull().sum()
# Out:
# InvoiceNo                 0
# StockCode                 0
# Description               0
# Quantity                  0
# InvoiceDate               0
# UnitPrice                 0
# CustomerID          8098080
# Country                   0
# freq_Description          0
# Count                     0
# dtype: int64

# %%
df2.drop(columns=["freq_Description", "Count"], inplace=True)
df2.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>InvoiceNo</th>
#       <th>StockCode</th>
#       <th>Description</th>
#       <th>
td>
#       <td>United Kingdom</td>
#     </tr>
#   </tbody>
# </table>
# <p>2460 rows x 8 columns</p>
# </div>

# %%
## Feature Engineering

# %%
df4 = df3.copy()
df4['TotalSales']=df4['Quantity']*df4['UnitPrice']
df4.head(3)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>InvoiceNo</th>
#       <th>StockCode</th>
#       <th>Description</th>
#       <th>Quantity</th>
#       <th>InvoiceDate</th>
#       <th>UnitPrice</th>
#       <th>CustomerID</th>
#       <th>Country</th>
#       <th>TotalSales</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>536365</td>
#       <td>85123A</td>
#       <td>WHITE HANGING HEART T-LIGHT HOLDER</td>
#       <td>6</td>
#       <td>2010-12-01 08:26:00</td>
#       <td>2.55</td>
#       <td>17850.0</td>
#       <td>United Kingdom</td>
#       <td>15.30</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>536365</td>
#       <td>71053</td>
#       <td>WHITE METAL LANTERN</td>
#       <td>6</td>
#       <td>2010-12-01 08:26:00</td>
#       <td>3.39</td>
#       <td>17850.0</td>
#       <td>United Kingdom</td>
#       <td>20.34</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>536365</td>
#       <td>84406B</td>
#       <td>CREAM CUPID HEARTS COAT HANGER</td>
#       <td>8</td>
#       <td>2010-12-01 08:26:00</td>
#       <td>2.75</td>
#       <td>17850.0</td>
#       <td>United Kingdom</td>
#       <td>22.00</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31806240 entries, 0 to 32514539
# Data columns (total 9 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   InvoiceNo    object
#  1   StockCode    object
#  2   Description  object
#  3   Quantity     int64
#  4   InvoiceDate  datetime64[ns]
#  5   UnitPrice    float64
#  6   CustomerID   float64
#  7   Country      object
#  8   TotalSales   float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(4)
# memory usage: 2.4+ GB

# %%
## Feature Engineering is done till here
df4['Month']=df4["InvoiceDate"].dt.month
df4.head(3)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>InvoiceNo</th>
#       <th>StockCode</th>
#       <th>Description</th>
#       <th>Quantity</th>
#       <th>InvoiceDate</th>
#       <th>UnitPrice</th>
#       <th>CustomerID</th>
#       <th>Country</th>
#       <th>TotalSales</th>
#       <th>Month</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>536365</td>
#       <td>85123A</td>
#       <td>WHITE HANGING HEART T-LIGHT HOLDER</td>
#       <td>6</td>
#       <td>2010-12-01 08:26:00</td>
#       <td>2.55</td>
#       <td>17850.0</td>
#       <td>United Kingdom</td>
#       <td>15.30</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>536365</td>
#       <td>71053</td>
#       <td>WHITE METAL LANTERN</td>
#       <td>6</td>
#       <td>2010-12-01 08:26:00</td>
#       <td>3.39</td>
#       <td>17850.0</td>
#       <td>United Kingdom</td>
#       <td>20.34</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>536365</td>
#       <td>84406B</td>
#       <td>CREAM CUPID HEARTS COAT HANGER</td>
#       <td>8</td>
#       <td>2010-12-01 08:26:00</td>
#       <td>2.75</td>
#       <td>17850.0</td>
#       <td>United Kingdom</td>
#       <td>22.00</td>
#       <td>12</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
#### Visuvalization & EDA
### Plot monthly sales

# %%
##   Bar chart
monthly_sales = df4.groupby('Month')['TotalSales'].sum()
monthly_sales.plot(kind='bar',title='Monthly Sales')
plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.show()

# %%
##Inline chart

monthly_sales = df4.groupby('Month')['TotalSales'].sum()
monthly_sales.plot(kind='line',title='Monthly Sales',marker="o")
plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.grid()
plt.show()

# %%
# prompt: plot horizontal bar chart for top5 countries by total sales

import matplotlib.pyplot as plt
# Group by country and sum total sales
country_sales = df4.groupby('Country')['TotalSales'].sum()

# Sort by total sales in descending order and get the top 5
top5_countries = country_sales.sort_values(ascending=False).head(5)

# Create the horizontal bar chart
plt.figure(figsize=(10, 6))  # Adjust figure size for better visualization
plt.barh(top5_countries.index, top5_countries.values)
plt.xlabel('Total Sales')
plt.ylabel('Country')
plt.title('Top 5 Countries by Total Sales')
plt.gca().invert_yaxis() # Invert y-axis to display highest sales on top
plt.show()

top5_countries
# Out:
# Country
# United Kingdom    5.415133e+08
# Netherlands       1.712678e+07
# EIRE              1.700724e+07
# Germany           1.373203e+07
# France            1.258291e+07
# Name: TotalSales, dtype: float64

# %%
# prompt: plot horizontal bar chart as above but this use percentage contribution show % on bar

import pandas as pd
import matplotlib.pyplot as plt

# ... (Your existing code for data loading and preprocessing) ...

# Group by country and sum total sales
country_sales = df4.groupby('Country')['TotalSales'].sum()

# Calculate percentage contribution
total_sales = country_sales.sum()
country_percentages = (country_sales / total_sales) * 100

# Sort by total sales in descending order and get the top 5
top5_countries = country_percentages.sort_values(ascending=False).head(5)

# Create the horizontal bar chart
plt.figure(figsize=(10, 6))
bars = plt.barh(top5_countries.index, top5_countries.values)
plt.xlabel('Percentage Contribution (%)')
plt.ylabel('Country')
plt.title('Top 5 Countries by Percentage Contribution to Total Sales')
plt.gca().invert_yaxis()

# Add percentage labels to the bars
for bar, percentage in zip(bars, top5_countries.values):
    plt.text(bar.get_width() + 0.5, bar.get_y() + bar.get_height()/2, f'{percentage:.1f}%',
             va='center', ha='left', color='black', fontsize=10)

plt.show()

# %%
###  Top 5 products based on total sales
product_wise_sales = df4.groupby('StockCode')['TotalSales'].sum()

top_5_products = product_wise_sales.sort_values(ascending=False).head(5)
top_5_products.plot(kind='barh', color='skyblue')
plt.title('Product-wise Sales')
plt.xlabel('Total Sales')
plt.ylabel('Product Stock Code')
plt.gca().invert_yaxis()  # To show the highest sales at the top
plt.show()

# %%
product_wise_sales.sort_values(ascending=False)
# Out:
# StockCode
# DOT       12374926.20
# 22423     10469084.40
# 23843     10108176.00
# 85123A     6271128.00
# 47566      5970259.80
#              ...
# 90084           51.00
# 21268           50.40
# 51014c          49.80
# 84227           25.20
# PADS             0.18
# Name: TotalSales, Length: 3922, dtype: float64

# %%
product_wise_sales.sum()
# Out:
# 640001072.64

# %%
df4[df4.StockCode=="DOT"]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>InvoiceNo</th>
#       <th>StockCode</th>
#       <th>Description</th>
#       <th>Quantity</th>
#       <th>InvoiceDate</th>
#       <th>UnitPrice</th>
#       <th>CustomerID</th>
#       <th>Country</th>
#       <th>TotalSales</th>
#       <th>Month</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1814</th>
#       <td>536544</td>
#       <td>DOT</td>
#       <td>DOTCOM POSTAGE</td>
#       <td>1</td>
#       <td>2010-12-01 14:32:00</td>
#       <td>569.77</td>
#       <td>NaN</td>
#       <td>United Kingdom</td>
#       <td>569.77</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>3041</th>
#       <td>536592</td>
#       <td>DOT</td>
#       <td>DOTCOM POSTAGE</td>
#       <td>1</td>
#       <td>2010-12-01 17:06:00</td>
#       <td>607.49</td>
#       <td>NaN</td>
#       <td>United Kingdom</td>
#       <td>607.49</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>5450</th>
#       <td>536862</td>
#       <td>DOT</td>
#       <td>DOTCOM POSTAGE</td>
#       <td>1</td>
#       <td>2010-12-03 11:13:00</td>
#       <td>254.43</td>
#       <td>NaN</td>
#       <td>United Kingdom</td>
#       <td>254.43</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>5545</th>
#       <td>536864</td>
#       <td>DOT</td>
#       <td>DOTCOM POSTAGE</td>
#       <td>1</td>
#       <td>2010-12-03 11:27:00</td>
#       <td>121.06</td>
#       <td>NaN</td>
#       <td>United Kingdom</td>
#       <td>121.06</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>5685</th>
#       <td>536865</td>
#       <td>DOT</td>
#       <td>DOTCOM POSTAGE</td>
#       <td>1</td>
#       <td>2010-12-03 11:28:00</td>
#       <td>498.47</td>
#       <td>NaN</td>
#       <td>United Kingdom</td>
#       <td>498.47</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>32509465</th>
#       <td>581219</td>
#       <td>DOT</td>
#       <td>DOTCOM POSTAGE</td>
#       <td>1</td>
#       <td>2011-12-08 09:28:00</td>
#       <td>1008.96</td>
#       <td>NaN</td>
#       <td>United Kingdom</td>
#       <td>1008.96</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>32509885</th>
#       <td>581238</td>
#       <td>DOT</td>
#       <td>DOTCOM POSTAGE</td>
#       <td>1</td>
#       <td>2011-12-08 10:53:00</td>
#       <td>1683.75</td>
#       <td>NaN</td>
#       <td>United Kingdom</td>
#       <td>1683.75</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>32511999</th>
#       <td>581439</td>
#       <td>DOT</td>
#       <td>DOTCOM POSTAGE</td>
#       <td>1</td>
#       <td>2011-12-08 16:30:00</td>
#       <td>938.59</td>
#       <td>NaN</td>
#       <td>United Kingdom</td>
#       <td>938.59</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>32513539</th>
#       <td>581492</td>
#       <td>DOT</td>
#       <td>DOTCOM POSTAGE</td>
#       <td>1</td>
#       <td>2011-12-09 10:03:00</td>
#       <td>933.17</td>
#       <td>NaN</td>
#       <td>United Kingdom</td>
#       <td>933.17</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>32514171</th>
#       <td>581498</td>
#       <td>DOT</td>
#       <td>DOTCOM POSTAGE</td>
#       <td>1</td>
#       <td>2011-12-09 10:26:00</td>
#       <td>1714.17</td>
#       <td>NaN</td>
#       <td>United Kingdom</td>
#       <td>1714.17</td>
#       <td>12</td>
#     </tr>
#   </tbody>
# </table>
# <p>42360 rows x 10 columns</p>
# </div>

# %%
for stock_code in top_5_products.index:
    description = df4[df4.StockCode==stock_code].Description.iloc[0]
    print(f"{stock_code} ==> {description}")
# Out:
# DOT ==> DOTCOM POSTAGE
# 22423 ==> REGENCY CAKESTAND 3 TIER
# 23843 ==> PAPER CRAFT , LITTLE BIRDIE
# 85123A ==> WHITE HANGING HEART T-LIGHT HOLDER
# 47566 ==> PARTY BUNTING

# %%
# prompt: Plot same chart as above for product sales but use percentage this time. Show % on the bar
# Assuming df4 is already created from the previous code
total_sales = product_wise_sales.sum()
percentages = (top_5_products / total_sales) * 100

plt.figure(figsize=(10, 6))
bars = plt.barh(top_5_products.index, percentages)
plt.xlabel('Percentage Contribution to Total Sales')
plt.ylabel('Product Stock Code')
plt.title('Top 5 Products by Percentage Contribution to Total Sales')
plt.grid(axis='x')

# Add percentage labels to the bars
for bar, percentage in zip(bars, percentages):
    plt.text(bar.get_width() + 0.5, bar.get_y() + bar.get_height()/2, f'{percentage:.1f}%', va='center')

plt.show()

# %%
df4['InvoiceDate'].max()
# Out:
# Timestamp('2011-12-09 12:50:00')

# %%
current_date = df4['InvoiceDate'].max() + pd.Timedelta(days=1)
current_date
# Out:
# Timestamp('2011-12-10 12:50:00')

# %%
rfm = df4.groupby('CustomerID').agg({
    'InvoiceDate': lambda x: (current_date - x.max()).days,
    'InvoiceNo': 'count',
    'TotalSales': 'sum'
})
rfm.columns = ['Recency', 'Frequency', 'Monetary']
rfm.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Recency</th>
#       <th>Frequency</th>
#       <th>Monetary</th>
#     </tr>
#     <tr>
#       <th>CustomerID</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>12346.0</th>
#       <td>326</td>
#       <td>60</td>
#       <td>4631016.0</td>
#     </tr>
#     <tr>
#       <th>12347.0</th>
#       <td>2</td>
#       <td>10920</td>
#       <td>258600.0</td>
#     </tr>
#     <tr>
#       <th>12348.0</th>
#       <td>75</td>
#       <td>1860</td>
#       <td>107834.4</td>
#     </tr>
#     <tr>
#       <th>12349.0</th>
#       <td>19</td>
#       <td>4380</td>
#       <td>105453.0</td>
#     </tr>
#     <tr>
#       <th>12350.0</th>
#       <td>310</td>
#       <td>1020</td>
#       <td>20064.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df4[df4.CustomerID==12346]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>InvoiceNo</th>
#       <th>StockCode</th>
#       <th>Description</th>
#       <th>Quantity</th>
#       <th>InvoiceDate</th>
#       <th>UnitPrice</th>
#       <th>CustomerID</th>
#       <th>Country</th>
#       <th>TotalSales</th>
#       <th>Month</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>61619</th>
#       <td>541431</td>
#       <td>23166</td>
#       <td>MEDIUM CERAMIC TOP STORAGE JAR</td>
#       <td>74215</td>
#       <td>2011-01-18 10:01:00</td>
#       <td>1.04</td>
#       <td>12346.0</td>
#       <td>United Kingdom</td>
#       <td>77183.6</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>603528</th>
#       <td>541431</td>
#       <td>23166</td>
#       <td>MEDIUM CERAMIC TOP STORAGE JAR</td>
#       <td>74215</td>
#       <td>2011-01-18 10:01:00</td>
#       <td>1.04</td>
#       <td>12346.0</td>
#       <td>United Kingdom</td>
#       <td>77183.6</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1145437</th>
#       <td>541431</td>
#       <td>23166</td>
#       <td>MEDIUM CERAMIC TOP STORAGE JAR</td>
#       <td>74215</td>
#       <td>2011-01-18 10:01:00</td>
#       <td>1.04</td>
#       <td>12346.0</td>
#       <td>United Kingdom</td>
#       <td>77183.6</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1687346</th>
#       <td>541431</td>
#       <td>23166</td>
#       <td>MEDIUM CERAMIC TOP STORAGE JAR</td>
#       <td>74215</td>
#       <td>2011-01-18 10:01:00</td>
#       <td>1.04</td>
#       <td>12346.0</td>
#       <td>United Kingdom</td>
#       <td>77183.6</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2229255</th>
#       <td>541431</td>
#       <td>23166</td>
#       <td>MEDIUM CERAMIC TOP STORAGE JAR</td>
#       <td>74215</td>
#       <td>2011-01-18 10:01:00</td>
#       <td>1.04</td>
#       <td>12346.0</td>
#       <td>United Kingdom</td>
#       <td>77183.6</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2771164</th>
#       <td>541431</td>
#       <td>23166</td>
#       <td>MEDIUM CERAMIC TOP STORAGE JAR</td>
#       <td>74215</td>
#       <td>2011-01-18 10:01:00</td>
#       <td>1.04</td>
#       <td>12346.0</td>
#       <td>United Kingdom</td>
#       <td>77183.6</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>3313073</th>
#       <td>541431</td>
#       <td>23166</td>
#       <td>MEDIUM CERAMIC TOP STORAGE JAR</td>
#       <td>74215</td>
#       <td>2011-01-18 10:01:00</td>
#       <td>1.04</td>
#       <td>12346.0</td>
#       <td>United Kingdom</td>
#       <td>77183.6</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>3854982</th>
#       <td>541431</td>
#       <td>23166</td>
#       <td>MEDIUM CERAMIC TOP STORAGE JAR</td>
#       <td>74215</td>
#       <td>2011-01-18 10:01:00</td>
#       <td>1.04</td>
#       <td>12346.0</td>
#       <td>United Kingdom</td>
#       <td>77183.6</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>4396891</th>
#       <td>541431</td>
#       <td>23166</td>
#       <td>MEDIUM CERAMIC TOP STORAGE JAR</td>
#       <td>74215</td>
#       <td>2011-01-18 10:01:00</td>
#       <td>1.04</td>
#       <td>12346.0</td>
#       <td>United Kingdom</td>
#       <td>77183.6</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>4938800</th>
#       <td>541431</td>
#       <td>23166</td>
#       <td>MEDIUM CERAMIC TOP STORAGE JAR</td>
#       <td>74215</td>
#       <td>2011-01-18 10:01:00</td>
#       <td>1.04</td>
#       <td>12346.0</td>
#       <td>United Kingdom</td>
#       <td>77183.6</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>5480709</th>
#       <td>541431</td>
#       <td>23166</td>
#       <td>MEDIUM CERAMIC TOP STORAGE JAR</td>
#       <td>74215</td>
#       <td>2011-01-18 10:01:00</td>
#       <td>1.04</td>
#       <td>12346.0</td>
#       <td>United Kingdom</td>
#       <td>77183.6</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>6022618</th>
#       <td>541431</td>
#       <td>23166</td>
#       <td>MEDIUM CERAMIC TOP STORAGE JAR</td>
#       <td>74215</td>
#       <td>2011-01-18 10:01:00</td>
#       <td>1.04</td>
#       <td>12346.0</td>
#       <td>United Kingdom</td>
#       <td>77183.6</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>6564527</th>
#       <td>541431</td>
#       <td>23166</td>
#       <td>MEDIUM CERAMIC TOP STORAGE JAR</td>
#       <td>74215</td>
#       <td>2011-01-18 10:01:00</td>
#       <td>1.04</td>
#       <td>12346.0</td>
#       <td>United Kingdom</td>
#       <td>77183.6</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>7106436</th>
#       <td>541431</td>
#       <td>23166</td>
#       <td>MEDIUM CERAMIC TOP STORAGE JAR</td>
#       <td>74215</td>
#       <td>2011-01-18 10:01:00</td>
#       <td>1.04</td>
#       <td>12346.0</td>
#       <td>United Kingdom</td>
#       <td>77183.6</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>7648345</th>
#       <td>541431</td>
#       <td>23166</td>
#       <td>MEDIUM CERAMIC TOP STORAGE JAR</td>
#       <td>74215</td>
#       <td>2011-01-18 10:01:00</td>
#       <td>1.04</td>
#       <td>12346.0</td>
#       <td>United Kingdom</td>
#       <td>77183.6</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>8190254</th>
#       <td>541431</td>
#       <td>23166</td>
#       <td>MEDIUM CERAMIC TOP STORAGE JAR</td>
#       <td>74215</td>
#       <td>2011-01-18 10:01:00</td>
#       <td>1.04</td>
#       <td>12346.0</td>
#       <td>United Kingdom</td>
#       <td>77183.6</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>8732163</th>
#       <td>541431</td>
#       <td>23166</td>
#       <td>MEDIUM CERAMIC TOP STORAGE JAR</td>
#       <td>74215</td>
#       <td>2011-01-18 10:01:00</td>
#       <td>1.04</td>
#       <td>12346.0</td>
#       <td>United Kingdom</td>
#       <td>77183.6</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>9274072</th>
#       <td>541431</td>
#       <td>23166</td>
#       <td>MEDIUM CERAMIC TOP STORAGE JAR</td>
#       <td>74215</td>
#       <td>2011-01-18 10:01:00</td>
#       <td>1.04</td>
#       <td>12346.0</td>
#       <td>United Kingdom</td>
#       <td>77183.6</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>9815981</th>
#       <td>541431</td>
#       <td>23166</td>
#       <td>MEDIUM CERAMIC TOP STORAGE JAR</td>
#       <td>74215</td>
#       <td>2011-01-18 10:01:00</td>
#       <td>1.04</td>
#       <td>12346.0</td>
#       <td>United Kingdom</td>
#       <td>77183.6</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>10357890</th>
#       <td>541431</td>
#       <td>23166</td>
#       <td>MEDIUM CERAMIC TOP STORAGE JAR</td>
#       <td>74215</td>
#       <td>2011-01-18 10:01:00</td>
#       <td>1.04</td>
#       <td>12346.0</td>
#       <td>United Kingdom</td>
#       <td>77183.6</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>10899799</th>
#       <td>541431</td>
#       <td>23166</td>
#       <td>MEDIUM CERAMIC TOP STORAGE JAR</td>
#       <td>74215</td>
#       <td>2011-01-18 10:01:00</td>
#       <td>1.04</td>
#       <td>12346.0</td>
#       <td>United Kingdom</td>
#       <td>77183.6</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>11441708</th>
#       <td>541431</td>
#       <td>23166</td>
#       <td>MEDIUM CERAMIC TOP STORAGE JAR</td>
#       <td>74215</td>
#       <td>2011-01-18 10:01:00</td>
#       <td>1.04</td>
#       <td>12346.0</td>
#       <td>United Kingdom</td>
#       <td>77183.6</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>11983617</th>
#       <td>541431</td>
#       <td>23166</td>
#       <td>MEDIUM CERAMIC TOP STORAGE JAR</td>
#       <td>74215</td>
#       <td>2011-01-18 10:01:00</td>
#       <td>1.04</td>
#       <td>12346.0</td>
#       <td>United Kingdom</td>
#       <td>77183.6</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>12525526</th>
#       <td>541431</td>
#       <td>23166</td>
#       <td>MEDIUM CERAMIC TOP STORAGE JAR</td>
#       <td>74215</td>
#       <td>2011-01-18 10:01:00</td>
#       <td>1.04</td>
#       <td>12346.0</td>
#       <td>United Kingdom</td>
#       <td>77183.6</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>13067435</th>
#       <td>541431</td>
#       <td>23166</td>
#       <td>MEDIUM CERAMIC TOP STORAGE JAR</td>
#       <td>74215</td>
#       <td>2011-01-18 10:01:00</td>

# %%
df4[df4.CustomerID==12347]["TotalSales"].sum()
# Out:
# 258599.99999999997

# %%
# Segment Customers based on RFM
rfm['R_Segment'] = pd.qcut(rfm['Recency'], 4, labels=[4, 3, 2, 1])
rfm['F_Segment'] = pd.qcut(rfm['Frequency'], 4, labels=[1, 2, 3, 4])
rfm['M_Segment'] = pd.qcut(rfm['Monetary'], 4, labels=[1, 2, 3, 4])
rfm['RFM_Score'] = rfm[['R_Segment', 'F_Segment', 'M_Segment']].sum(axis=1)
rfm
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Recency</th>
#       <th>Frequency</th>
#       <th>Monetary</th>
#       <th>R_Segment</th>
#       <th>F_Segment</th>
#       <th>M_Segment</th>
#       <th>RFM_Score</th>
#     </tr>
#     <tr>
#       <th>CustomerID</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>12346.0</th>
#       <td>326</td>
#       <td>60</td>
#       <td>4631016.0</td>
#       <td>1</td>
#       <td>1</td>
#       <td>4</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>12347.0</th>
#       <td>2</td>
#       <td>10920</td>
#       <td>258600.0</td>
#       <td>4</td>
#       <td>4</td>
#       <td>4</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>12348.0</th>
#       <td>75</td>
#       <td>1860</td>
#       <td>107834.4</td>
#       <td>2</td>
#       <td>2</td>
#       <td>4</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>12349.0</th>
#       <td>19</td>
#       <td>4380</td>
#       <td>105453.0</td>
#       <td>3</td>
#       <td>3</td>
#       <td>4</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>12350.0</th>
#       <td>310</td>
#       <td>1020</td>
#       <td>20064.0</td>
#       <td>1</td>
#       <td>1</td>
#       <td>2</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>18280.0</th>
#       <td>278</td>
#       <td>600</td>
#       <td>10836.0</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>18281.0</th>
#       <td>181</td>
#       <td>420</td>
#       <td>4849.2</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>18282.0</th>
#       <td>8</td>
#       <td>720</td>
#       <td>10683.0</td>
#       <td>4</td>
#       <td>1</td>
#       <td>1</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>18283.0</th>
#       <td>4</td>
#       <td>45360</td>
#       <td>125692.8</td>
#       <td>4</td>
#       <td>4</td>
#       <td>4</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>18287.0</th>
#       <td>43</td>
#       <td>4200</td>
#       <td>110236.8</td>
#       <td>3</td>
#       <td>3</td>
#       <td>4</td>
#       <td>10</td>
#     </tr>
#   </tbody>
# </table>
# <p>4338 rows x 7 columns</p>
# </div>

# %%
###RFM Analysis : Recency, frequnecy, Monetary
rfm.sort_values(by='RFM_Score', ascending=False)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Recency</th>
#       <th>Frequency</th>
#       <th>Monetary</th>
#       <th>R_Segment</th>
#       <th>F_Segment</th>
#       <th>M_Segment</th>
#       <th>RFM_Score</th>
#     </tr>
#     <tr>
#       <th>CustomerID</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>12347.0</th>
#       <td>2</td>
#       <td>10920</td>
#       <td>258600.0</td>
#       <td>4</td>
#       <td>4</td>
#       <td>4</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>12362.0</th>
#       <td>3</td>
#       <td>15960</td>
#       <td>313573.8</td>
#       <td>4</td>
#       <td>4</td>
#       <td>4</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>12417.0</th>
#       <td>3</td>
#       <td>11520</td>
#       <td>218946.0</td>
#       <td>4</td>
#       <td>4</td>
#       <td>4</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>12423.0</th>
#       <td>1</td>
#       <td>7500</td>
#       <td>111558.6</td>
#       <td>4</td>
#       <td>4</td>
#       <td>4</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>12433.0</th>
#       <td>1</td>
#       <td>25200</td>
#       <td>802552.2</td>
#       <td>4</td>
#       <td>4</td>
#       <td>4</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>18224.0</th>
#       <td>264</td>
#       <td>600</td>
#       <td>9537.0</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>18227.0</th>
#       <td>218</td>
#       <td>300</td>
#       <td>5625.0</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>18269.0</th>
#       <td>366</td>
#       <td>420</td>
#       <td>10116.0</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>18280.0</th>
#       <td>278</td>
#       <td>600</td>
#       <td>10836.0</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>18281.0</th>
#       <td>181</td>
#       <td>420</td>
#       <td>4849.2</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>3</td>
#     </tr>
#   </tbody>
# </table>
# <p>4338 rows x 7 columns</p>
# </div>

# %%
# Create a basket matrix for association rule mining
customer_last_purchase = df4.groupby("CustomerID")['InvoiceDate'].max()
customer_last_purchase.head(5)
# Out:
# CustomerID
# 12346.0   2011-01-18 10:01:00
# 12347.0   2011-12-07 15:52:00
# 12348.0   2011-09-25 13:13:00
# 12349.0   2011-11-21 09:51:00
# 12350.0   2011-02-02 16:01:00
# Name: InvoiceDate, dtype: datetime64[ns]

# %%
type(customer_last_purchase)
# Out:
# fireducks.pandas.series.Series

# %%
current_date
# Out:
# Timestamp('2011-12-10 12:50:00')

# %%
# Define churn threshold (e.g., 90 days without purchase)
churn_threshold = 90
churned_customers = customer_last_purchase[customer_last_purchase > churn_threshold]
churned_customers.head(5)

# %%
print("Number of Churned Customers:", len(churned_customers))
plt.figure(figsize=(10, 6))
plt.hist(customer_last_purchase, bins=50, color='red', alpha=0.7)
plt.axvline(churn_threshold, color='black', linestyle='dashed', linewidth=2)
plt.title('Customer Churn Distribution')
plt.xlabel('Days Since Last Purchase')
plt.ylabel('Number of Customers')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/fireducks/core.py in _evaluate(values, options, evalLogger)
#     371     try:
# --> 372         return fire.evaluate(values, wrapper, package="fireducks")
#     373     except fireducks_ext.IndexingError as e:
#
# /usr/local/lib/python3.11/dist-packages/firefw/runtime.py in wrapper(*args, **kwargs)
#      30         try:
# ---> 31             ret = func(*args, **kwargs)
#      32         finally:
#
# /usr/local/lib/python3.11/dist-packages/firefw/runtime.py in evaluate(values, executor, package)
#      71
# ---> 72     ret = executor(source, input_values, output_values)
#      73
#
# /usr/local/lib/python3.11/dist-packages/fireducks/core.py in wrapper(ir, input_values, output_values)
#     363
# --> 364         return fireducks_ext.execute(
#     365             context().ext_context,
#
# NotImplementedError: Function 'greater' has no kernel matching input types (timestamp[ns], int64)
#
# During handling of the above exception, another exception occurred:
#
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-52-c5e887864ace> in <cell line: 0>()
# ----> 1 print("Number of Churned Customers:", len(churned_customers))
#       2 plt.figure(figsize=(10, 6))
#       3 plt.hist(customer_last_purchase, bins=50, color='red', alpha=0.7)
#       4 plt.axvline(churn_threshold, color='black', linestyle='dashed', linewidth=2)
#       5 plt.title('Customer Churn Distribution')
#
# /usr/local/lib/python3.11/dist-packages/fireducks/pandas/series.py in __len__(self)
#     841
#     842     def __len__(self):
# --> 843         return self.shape[0]
#     844
#     845     def __neg__(self):
#
# /usr/local/lib/python3.11/dist-packages/fireducks/pandas/series.py in shape(self)
#    1312
#    1313         value = ir.get_shape(self._value)
# -> 1314         shape = fireducks.core.evaluate([value])[0]
#    1315         return (shape.y,)
#    1316
#
# /usr/local/lib/python3.11/dist-packages/fireducks/core.py in evaluate(values, options, evalLogger)
#     391 ):
#     392     with tracing.scope(tracing.Level.DEFAULT, "fireducks.core.evaluate"):
# --> 393         ret = _evaluate(values, options, evalLogger)
#     394     return ret
#     395
#
# /usr/local/lib/python3.11/dist-packages/fireducks/core.py in _evaluate(values, options, evalLogger)
#     378         raise pandas.errors.MergeError(e)
#     379     except fireducks_ext.NotImplementedError as e:
# --> 380         raise NotImplementedError(e)
#     381     except fireducks_ext.SpecificationError as e:
#     382         raise pandas.errors.SpecificationError(e)
#
# NotImplementedError: Function 'greater' has no kernel matching input types (timestamp[ns], int64)

# %%
import time
import pandas as pd


# ... (rest of your code) ...

stime = time.time()  # Record the start time at the beginning of the relevant section

# ... (code you are timing) ...

print(f"[{pd.__name__}] total time taken: {time.time() - stime} sec")

# %%
print(f"[{pd.__name__}] total time taken: {time.time() - stime} sec")
